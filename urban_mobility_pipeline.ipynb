# %%
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: IPython in c:\projects\final_bda\new\.venv\lib\site-packages (from import-ipynb) (9.7.0)
# Requirement already satisfied: nbformat in c:\projects\final_bda\new\.venv\lib\site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: colorama>=0.4.4 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\projects\final_bda\new\.venv\lib\site-packages (from IPython->import-ipynb) (4.15.0)
# Requirement already satisfied: wcwidth in c:\projects\final_bda\new\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\projects\final_bda\new\.venv\lib\site-packages (from jedi>=0.18.1->IPython->import-ipynb) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in c:\projects\final_bda\new\.venv\lib\site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (0.2.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\projects\final_bda\new\.venv\lib\site-packages (from nbformat->import-ipynb) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\projects\final_bda\new\.venv\lib\site-packages (from nbformat->import-ipynb) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\projects\final_bda\new\.venv\lib\site-packages (from nbformat->import-ipynb) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\projects\final_bda\new\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\projects\final_bda\new\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\projects\final_bda\new\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\projects\final_bda\new\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\projects\final_bda\new\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.5.0)
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.2

# %%
import os

print("Exists:", os.path.exists("core/mongodb_manager.py"))
if os.path.exists("core/mongodb_manager.py"):
    with open("core/mongodb_manager.py") as f:
        print("First 10 lines:\n", "".join([next(f) for _ in range(10)]))
# Out:
# Exists: True
# First 10 lines:
#  #!/usr/bin/env python
# # coding: utf-8
#
# # In[2]:
#
#
# get_ipython().system('pip install import-ipynb')
#
#
# # In[10]:

# %%
import import_ipynb

from config.settings import Config
from core.mongodb_manager import MongoDBManager
from spark.processor import SparkProcessor
from analysis.engine import AnalysisEngine
from reporting.summary import generate_summary_report
import findspark
import sys

def main():
    print(" Starting Data Processing Pipeline")
    print("=" * 50)
    
    # Step 1: Spark Setup
    print("\n1. Spark Setup")
    try:
        findspark.init()
        from pyspark.sql import SparkSession
        spark = SparkSession.builder \
            .appName("CityDataAnalysis") \
            .config("spark.mongodb.read.connection.uri", Config.MONGO_URI) \
            .config("spark.mongodb.write.connection.uri", Config.MONGO_URI) \
            .getOrCreate()
        spark.sparkContext.setLogLevel("ERROR")
        print(" Spark setup successful")
    except Exception as e:
        print(" Spark setup failed. Please install Spark dependencies.")
        print("Run: pip install pyspark findspark")
        print(f"Error: {e}")
        return

    # Step 2: MongoDB Setup and Data Import
    print("\n2. MongoDB Setup and Data Import")
    try:
        mongo_manager = MongoDBManager()
        for city in ['delhi', 'bangalore']:
            print(f"\n Processing {city.upper()}...")
            success = mongo_manager.import_city_data(city)
            if success:
                print(f"Successfully imported {city} data")
            else:
                print(f" Failed to import {city} data")

        print("\n" + "=" * 50)
        mongo_manager.get_database_stats()

    except Exception as e:
        print(f"MongoDB operations failed: {e}")
        spark.stop()
        return

    # Step 3: Spark Processing
    print("\n3.Spark Data Processing")
    spark_processor = SparkProcessor(spark)

    all_analysis_results = []
    for city in ['delhi', 'bangalore']:
        print(f"\n Processing {city.upper()} with Spark...")
        results = spark_processor.process_city_data(city, mongo_manager)
        if results:
            spark_processor.save_spark_results(results, city)
            print(f" Successfully processed {city} data")
        else:
            print(f" Failed to process {city} data with Spark")

    # Step 4: Analysis and Visualization
    print("\n4. Data Analysis and Visualization")
    analysis_engine = AnalysisEngine()

    for city in ['delhi', 'bangalore']:
        print(f"\nAnalyzing {city.upper()}...")
        analysis_results = analysis_engine.perform_comprehensive_analysis(city)
        if analysis_results:
            all_analysis_results.append(analysis_results)
        data = analysis_engine.load_analysis_data(city)
        if data:
            analysis_engine.create_comprehensive_visualizations(city, data)

    # Step 5: Generate Summary Report
    print("\n5. 📋 Generating Summary Report")
    generate_summary_report(all_analysis_results)

    # Clean up Spark
    if spark:
        spark.stop()
        print("Spark session stopped")

    print("\nPipeline completed successfully!")
    print("Check the 'data/outputs/' folder for results and visualizations")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 4
#       1 import import_ipynb
#       3 from config.settings import Config
# ----> 4 from core.mongodb_manager import MongoDBManager
#       5 from spark.processor import SparkProcessor
#       6 from analysis.engine import AnalysisEngine
#
# ImportError: cannot import name 'MongoDBManager' from 'core.mongodb_manager' (unknown location)
