# %%
# Install packages that don't require compilation first
! pip install python-dotenv jupyter requests beautifulsoup4 selenium tweepy pymongo dnspython pandas numpy matplotlib seaborn plotly folium textblob tabula-py

# Install geopandas and its dependencies (this will handle GDAL/Fiona properly)
! pip install geopandas

# If the above fails, try installing from conda-forge channel:
! pip install --pre -f https://wheelhouse.gdal.org/ gdal fiona

# Install these lightweight alternatives
# !pip install geopy shapely pyproj contextily
# Out:
# ...
# Could not find platform independent libraries <prefix>
# ...
#   Using cached geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached pyogrio-0.11.1.tar.gz (287 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Could not find platform independent libraries <prefix>
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       Could not find platform independent libraries <prefix>
#       GDAL_VERSION must be provided as an environment variable or as --gdalversion command line argument
#       [end of output]
#
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Keep your existing connection code exactly as is
# !pip install pymongo --quiet
from pymongo import MongoClient

MONGO_URI = os.getenv('MONGO_URI')

from pymongo import MongoClient

client = MongoClient(
    MONGO_URI,
    tls=True,
    tlsAllowInvalidCertificates=True
)

try:
    client.admin.command("ping")
    print("Connected successfully!")
    db = client['urban_mobility']
    print("Collections:", db.list_collection_names())
except Exception as e:
    print("Connection failed:", e)
# Out:
# Could not find platform independent libraries <prefix>
